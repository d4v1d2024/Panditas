# %%
# !pip install panditas 
# !pip install seaborn
# !pip install plotly
# Out:
# ERROR: Could not find a version that satisfies the requirement panditas (from versions: none)
# ERROR: No matching distribution found for panditas
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\Pc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\Pc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\Pc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

# Especifica la ruta de tu archivo CSV
archivo_csv = "c:/Users/Pc/Desktop/Data Science/SRI_ComprasVentas/sri_ventas_2023.csv"

# Utiliza pandas para leer el archivo CSV con la codificación 'latin-1'
sri_ventas_2023 = pd.read_csv(archivo_csv, encoding='latin-1', sep='|')

# Ahora, 'datos' es un DataFrame de pandas que contiene tus datos
# Puedes trabajar con los datos como desees
print(sri_ventas_2023)
# Out:
#         AÑO  MES CODIGO_SECTOR_N1        PROVINCIA       CANTON  \
# 0      2023    1                A           GUAYAS    GUAYAQUIL
# 1      2023    4                J           EL ORO        PIÑAS
# 2      2023    2                N           MANABI  MONTECRISTI
# 3      2023   12                P         IMBABURA    COTACACHI
# 4      2023    4                G           MANABI        CHONE
# ...     ...  ...              ...              ...          ...
# 47617  2023    4                E         COTOPAXI       PANGUA
# 47618  2023    4                V           GUAYAS  SAMBORONDON
# 47619  2023    3                X           EL ORO       ZARUMA
# 47620  2023    5                V  MORONA SANTIAGO       TAISHA
# 47621  2023    6                X       CHIMBORAZO      CUMANDA
#
#       VENTAS_NETAS_TARIFA_12 VENTAS_NETAS_TARIFA_0   EXPORTACIONES  \
# 0              11293702,9100        202181393,9900  261329528,1700
# ...

# %%
# Visualizacion de los primeros datos
print(sri_ventas_2023.head())
# Out:
#     AÑO  MES CODIGO_SECTOR_N1 PROVINCIA       CANTON VENTAS_NETAS_TARIFA_12  \
# 0  2023    1                A    GUAYAS    GUAYAQUIL          11293702,9100
# 1  2023    4                J    EL ORO        PIÑAS            214847,2800
# 2  2023    2                N    MANABI  MONTECRISTI             18724,5100
# 3  2023   12                P  IMBABURA    COTACACHI              2811,7000
# 4  2023    4                G    MANABI        CHONE           5060786,6400
#
#   VENTAS_NETAS_TARIFA_0   EXPORTACIONES COMPRAS_NETAS_TARIFA_12  \
# 0        202181393,9900  261329528,1700           86677999,9900
# 1                0,0000          0,0000              92101,5000
# 2             1833,7300          0,0000               9995,1000
# 3           140340,2600          0,0000              13300,9500
# 4          4528391,8700          0,0000            5150866,1800
#
#   COMPRAS_NETAS_TARIFA_0  IMPORTACIONES  COMPRAS_RISE   TOTAL_COMPRAS  \
# ...

# %%
# información de la base de datos
print(sri_ventas_2023.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47622 entries, 0 to 47621
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AÑO                      47622 non-null  int64
#  1   MES                      47622 non-null  int64
#  2   CODIGO_SECTOR_N1         47622 non-null  object
#  3   PROVINCIA                47622 non-null  object
#  4   CANTON                   47622 non-null  object
#  5   VENTAS_NETAS_TARIFA_12   47622 non-null  object
#  6   VENTAS_NETAS_TARIFA_0    47622 non-null  object
#  7   EXPORTACIONES            47622 non-null  object
#  8   COMPRAS_NETAS_TARIFA_12  47622 non-null  object
#  9   COMPRAS_NETAS_TARIFA_0   47622 non-null  object
#  10  IMPORTACIONES            47622 non-null  object
#  11  COMPRAS_RISE             47622 non-null  object
#  12  TOTAL_COMPRAS            47622 non-null  object
#  13  TOTAL_VENTAS             47622 non-null  object
# ...

# %%
#Tratar valores nulos
print(sri_ventas_2023.isnull().sum())
# Out:
# AÑO                        0
# MES                        0
# CODIGO_SECTOR_N1           0
# PROVINCIA                  0
# CANTON                     0
# VENTAS_NETAS_TARIFA_12     0
# VENTAS_NETAS_TARIFA_0      0
# EXPORTACIONES              0
# COMPRAS_NETAS_TARIFA_12    0
# COMPRAS_NETAS_TARIFA_0     0
# IMPORTACIONES              0
# COMPRAS_RISE               0
# TOTAL_COMPRAS              0
# TOTAL_VENTAS               0
# dtype: int64

# %%
sri_ventas_2023= sri_ventas_2023.drop_duplicates()

# %%
# Sacamos los peimeros datos de la base
sri_ventas_2023.head(20)
# Out:
#      AÑO  MES CODIGO_SECTOR_N1        PROVINCIA           CANTON  \
# 0   2023    1                A           GUAYAS        GUAYAQUIL
# 1   2023    4                J           EL ORO            PIÑAS
# 2   2023    2                N           MANABI      MONTECRISTI
# 3   2023   12                P         IMBABURA        COTACACHI
# 4   2023    4                G           MANABI            CHONE
# 5   2023    9                M           CARCHI         MONTUFAR
# 6   2023    5                M             LOJA             LOJA
# 7   2023    6                G            AZUAY     SANTA ISABEL
# 8   2023    4                P           EL ORO         EL GUABO
# 9   2023   12                O           EL ORO            PIÑAS
# 10  2023   12                S  MORONA SANTIAGO  LIMON - INDANZA
# 11  2023    2                M          BOLIVAR         GUARANDA
# 12  2023    7                O  MORONA SANTIAGO          LOGROÑO
# ...

# %%
sri_ventas_2023. describe()
# Out:
#            AÑO          MES
# count  47622.0  47622.00000
# mean    2023.0      6.51787
# std        0.0      3.45778
# min     2023.0      1.00000
# 25%     2023.0      4.00000
# 50%     2023.0      6.00000
# 75%     2023.0     10.00000
# max     2023.0     12.00000

# %%
# Usamos este codigo para que lea a la variable como número decimal y no como objeto

df = pd.DataFrame(sri_ventas_2023)

df['TOTAL_COMPRAS'] = pd.to_numeric(df['TOTAL_COMPRAS'].astype(str).str.replace(',', '.'), errors='coerce')

df['TOTAL_VENTAS'] = pd.to_numeric(df['TOTAL_VENTAS'].astype(str).str.replace(',', '.'), errors='coerce')

df['COMPRAS_RISE'] = pd.to_numeric(df['COMPRAS_RISE'].astype(str).str.replace(',', '.'), errors='coerce')

df['IMPORTACIONES'] = pd.to_numeric(df['IMPORTACIONES'].astype(str).str.replace(',', '.'), errors='coerce')

df['COMPRAS_NETAS_TARIFA_0'] = pd.to_numeric(df['COMPRAS_NETAS_TARIFA_0'].astype(str).str.replace(',', '.'), errors='coerce')

df['COMPRAS_NETAS_TARIFA_12'] = pd.to_numeric(df['COMPRAS_NETAS_TARIFA_12'].astype(str).str.replace(',', '.'), errors='coerce')

df['EXPORTACIONES'] = pd.to_numeric(df['EXPORTACIONES'].astype(str).str.replace(',', '.'), errors='coerce')

df['VENTAS_NETAS_TARIFA_0'] = pd.to_numeric(df['VENTAS_NETAS_TARIFA_0'].astype(str).str.replace(',', '.'), errors='coerce')

df['VENTAS_NETAS_TARIFA_12'] = pd.to_numeric(df['VENTAS_NETAS_TARIFA_12'].astype(str).str.replace(',', '.'), errors='coerce')

df.head(51)
# Out:
#      AÑO  MES CODIGO_SECTOR_N1        PROVINCIA                       CANTON  \
# 0   2023    1                A           GUAYAS                    GUAYAQUIL
# 1   2023    4                J           EL ORO                        PIÑAS
# 2   2023    2                N           MANABI                  MONTECRISTI
# 3   2023   12                P         IMBABURA                    COTACACHI
# 4   2023    4                G           MANABI                        CHONE
# 5   2023    9                M           CARCHI                     MONTUFAR
# 6   2023    5                M             LOJA                         LOJA
# 7   2023    6                G            AZUAY                 SANTA ISABEL
# 8   2023    4                P           EL ORO                     EL GUABO
# 9   2023   12                O           EL ORO                        PIÑAS
# 10  2023   12                S  MORONA SANTIAGO              LIMON - INDANZA
# ...

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47622 entries, 0 to 47621
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AÑO                      47622 non-null  int64
#  1   MES                      47622 non-null  int64
#  2   CODIGO_SECTOR_N1         47622 non-null  object
#  3   PROVINCIA                47622 non-null  object
#  4   CANTON                   47622 non-null  object
#  5   VENTAS_NETAS_TARIFA_12   47622 non-null  float64
#  6   VENTAS_NETAS_TARIFA_0    47622 non-null  float64
#  7   EXPORTACIONES            47622 non-null  float64
#  8   COMPRAS_NETAS_TARIFA_12  47622 non-null  float64
#  9   COMPRAS_NETAS_TARIFA_0   47622 non-null  float64
#  10  IMPORTACIONES            47622 non-null  float64
#  11  COMPRAS_RISE             47622 non-null  float64
#  12  TOTAL_COMPRAS            47622 non-null  float64
#  13  TOTAL_VENTAS             47622 non-null  float64
# ...

# %%
#Para calcular un aumento del 3%

df ['VENTAS_NETAS_TARIFA_15'] = df['VENTAS_NETAS_TARIFA_12']*1.03

df ['COMPRAS_NETAS_TARIFA_15'] =  df['COMPRAS_NETAS_TARIFA_12']*1.03
df
# Out:
#         AÑO  MES CODIGO_SECTOR_N1        PROVINCIA       CANTON  \
# 0      2023    1                A           GUAYAS    GUAYAQUIL
# 1      2023    4                J           EL ORO        PIÑAS
# 2      2023    2                N           MANABI  MONTECRISTI
# 3      2023   12                P         IMBABURA    COTACACHI
# 4      2023    4                G           MANABI        CHONE
# ...     ...  ...              ...              ...          ...
# 47617  2023    4                E         COTOPAXI       PANGUA
# 47618  2023    4                V           GUAYAS  SAMBORONDON
# 47619  2023    3                X           EL ORO       ZARUMA
# 47620  2023    5                V  MORONA SANTIAGO       TAISHA
# 47621  2023    6                X       CHIMBORAZO      CUMANDA
#
#        VENTAS_NETAS_TARIFA_12  VENTAS_NETAS_TARIFA_0  EXPORTACIONES  \
# 0                 11293702.91           2.021814e+08   2.613295e+08
# ...

# %%
df[(df['VENTAS_NETAS_TARIFA_12'] > 1000) & (df['VENTAS_NETAS_TARIFA_0'] > 1000)]
# Out:
#         AÑO  MES CODIGO_SECTOR_N1   PROVINCIA       CANTON  \
# 0      2023    1                A      GUAYAS    GUAYAQUIL
# 2      2023    2                N      MANABI  MONTECRISTI
# 3      2023   12                P    IMBABURA    COTACACHI
# 4      2023    4                G      MANABI        CHONE
# 5      2023    9                M      CARCHI     MONTUFAR
# ...     ...  ...              ...         ...          ...
# 47570  2023   11                K      MANABI        SUCRE
# 47573  2023   10                L  TUNGURAHUA        MOCHA
# 47600  2023    2                L      CARCHI      BOLIVAR
# 47603  2023   12                B     PASTAZA         MERA
# 47605  2023    1                K       AZUAY        GIRON
#
#        VENTAS_NETAS_TARIFA_12  VENTAS_NETAS_TARIFA_0  EXPORTACIONES  \
# 0                 11293702.91           2.021814e+08   2.613295e+08
# 2                    18724.51           1.833730e+03   0.000000e+00
# ...

# %%
group = df.groupby(['PROVINCIA']).agg({'VENTAS_NETAS_TARIFA_12': ['count', 'mean', 'max']})
group
# Out:
#                                VENTAS_NETAS_TARIFA_12                \
#                                                 count          mean
# PROVINCIA
# AZUAY                                            3062  2.115532e+06
# BOLIVAR                                          1451  9.629425e+04
# CARCHI                                           1240  1.462506e+05
# CAÑAR                                            1513  2.567365e+05
# CHIMBORAZO                                       2155  4.486180e+05
# COTOPAXI                                         1641  4.814818e+05
# EL ORO                                           3031  6.107147e+05
# ESMERALDAS                                       1607  2.808963e+05
# GALAPAGOS                                         663  3.396264e+05
# GUAYAS                                           5481  7.318871e+06
# IMBABURA                                         1385  7.758214e+05
# LOJA                                             3331  2.934652e+05
# ...

# %%
group_1_comp = df.groupby(['PROVINCIA']).agg({'TOTAL_COMPRAS': ['count', 'mean', 'max']})
group_1_comp
# Out:
#                                TOTAL_COMPRAS
#                                        count          mean           max
# PROVINCIA
# AZUAY                                   3062  2.752595e+06  4.062205e+08
# BOLIVAR                                 1451  2.310814e+05  1.007686e+07
# CARCHI                                  1240  5.388626e+05  3.305847e+07
# CAÑAR                                   1513  5.629656e+05  2.002355e+07
# CHIMBORAZO                              2155  7.090903e+05  7.681803e+07
# COTOPAXI                                1641  1.224430e+06  6.366169e+07
# EL ORO                                  3031  2.187163e+06  3.061244e+08
# ESMERALDAS                              1607  1.336335e+06  1.055552e+08
# GALAPAGOS                                663  6.765551e+05  1.892807e+07
# GUAYAS                                  5481  1.219949e+07  2.762420e+09
# IMBABURA                                1385  1.402726e+06  7.719633e+07
# ...

# %%
# !pip install matplotlib.pyplot
# Out:
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\Pc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# Graficar el número de compras por provincia
plt.figure(figsize=(40, 15))

# Graficar la media de compras por provincia
plt.subplot(1, 2, 2)
group_1_comp['TOTAL_COMPRAS']['mean'].plot(kind='bar', color='lightcoral')
plt.title('Media de Compras por Provincia')
plt.xlabel('Provincia')
plt.ylabel('Media de Compras')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
group_1_exp = df.groupby(['PROVINCIA']).agg({'EXPORTACIONES': ['count', 'mean', 'max']})
group_1_exp
# Out:
#                                EXPORTACIONES
#                                        count          mean           max
# PROVINCIA
# AZUAY                                   3062  7.230547e+04  1.520854e+07
# BOLIVAR                                 1451  3.236047e+03  8.121239e+05
# CARCHI                                  1240  2.794762e+04  1.089810e+06
# CAÑAR                                   1513  3.052335e+03  3.535853e+06
# CHIMBORAZO                              2155  3.850117e+03  1.114523e+06
# COTOPAXI                                1641  1.821142e+05  2.590259e+07
# EL ORO                                  3031  4.467535e+05  1.517134e+08
# ESMERALDAS                              1607  3.712242e+04  3.444147e+06
# GALAPAGOS                                663  8.537532e+03  5.010605e+05
# GUAYAS                                  5481  2.338542e+06  3.160917e+08
# IMBABURA                                1385  5.668739e+04  1.002621e+07
# ...

# %%
# Graficar el número de EXPORTACIONES por provincia
plt.figure(figsize=(40, 15))

# Graficar la media de EXPORTACIONES por provincia
plt.subplot(1, 2, 2)
group_1_exp['EXPORTACIONES']['mean'].plot(kind='bar', color='green')
plt.title('EXPORTACIONES por Provincia')
plt.xlabel('Provincia')
plt.ylabel('Media de EXPORTACIONES')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
sig = df[(df['TOTAL_COMPRAS'] > 1000000) & (df['TOTAL_VENTAS'] > 1000000)]
print(sig.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6628 entries, 0 to 47201
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AÑO                      6628 non-null   int64
#  1   MES                      6628 non-null   int64
#  2   CODIGO_SECTOR_N1         6628 non-null   object
#  3   PROVINCIA                6628 non-null   object
#  4   CANTON                   6628 non-null   object
#  5   VENTAS_NETAS_TARIFA_12   6628 non-null   float64
#  6   VENTAS_NETAS_TARIFA_0    6628 non-null   float64
#  7   EXPORTACIONES            6628 non-null   float64
#  8   COMPRAS_NETAS_TARIFA_12  6628 non-null   float64
#  9   COMPRAS_NETAS_TARIFA_0   6628 non-null   float64
#  10  IMPORTACIONES            6628 non-null   float64
#  11  COMPRAS_RISE             6628 non-null   float64
#  12  TOTAL_COMPRAS            6628 non-null   float64
#  13  TOTAL_VENTAS             6628 non-null   float64
# ...

# %%
group_2_comp = sig.groupby(['PROVINCIA']).agg({'TOTAL_COMPRAS': ['count', 'mean', 'max']})
group_2_comp
# Out:
#                                TOTAL_COMPRAS
#                                        count          mean           max
# PROVINCIA
# AZUAY                                    304  2.686661e+07  4.062205e+08
# BOLIVAR                                   69  2.346438e+06  1.007686e+07
# CARCHI                                    69  6.991679e+06  3.305847e+07
# CAÑAR                                    152  4.281336e+06  2.002355e+07
# CHIMBORAZO                               215  6.093369e+06  7.681803e+07
# COTOPAXI                                 214  7.972269e+06  6.366169e+07
# EL ORO                                   550  1.133465e+07  3.061244e+08
# ESMERALDAS                               178  1.074280e+07  1.055552e+08
# GALAPAGOS                                 77  4.586364e+06  1.892807e+07
# GUAYAS                                  1283  5.162312e+07  2.762420e+09
# IMBABURA                                 275  6.283016e+06  7.719633e+07
# ...

# %%
# Graficar el número de EXPORTACIONES por provincia
plt.figure(figsize=(40, 15))

# Graficar la media de EXPORTACIONES por provincia
plt.subplot(1, 2, 2)
group_2_comp['TOTAL_COMPRAS']['mean'].plot(kind='bar', color='Black')
plt.title('Media de COMPRAS por Provincia')
plt.xlabel('Provincia')
plt.ylabel('Media de COMPRAS')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
dif = (group_2_comp/ group_1_comp)* 100
dif
# Out:
#                                TOTAL_COMPRAS
#                                        count         mean    max
# PROVINCIA
# AZUAY                               9.928152   976.046593  100.0
# BOLIVAR                             4.755341  1015.416279  100.0
# CARCHI                              5.564516  1297.488216  100.0
# CAÑAR                              10.046266   760.496907  100.0
# CHIMBORAZO                          9.976798   859.321922  100.0
# COTOPAXI                           13.040829   651.100346  100.0
# EL ORO                             18.145826   518.235452  100.0
# ESMERALDAS                         11.076540   803.900286  100.0
# GALAPAGOS                          11.613876   677.899608  100.0
# GUAYAS                             23.408137   423.157876  100.0
# IMBABURA                           19.855596   447.914706  100.0
# LOJA                                7.054938  1147.237857  100.0
# LOS RIOS                           15.373459   578.439400  100.0
# ...

# %%
# Graficar la diferencia de compras por provincia
plt.figure(figsize=(45, 15))

# Graficar la media de compras por provincia
plt.subplot(1, 2, 2)
dif['TOTAL_COMPRAS']['count'].plot(kind='bar', color='blue')
plt.title('% COMPRAS SIGNIFICATIVAS')
plt.xlabel('Provincia')
plt.ylabel('COUNT')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from matplotlib.colors import ListedColormap, LinearSegmentedColormap, to_rgb
from matplotlib import rcParams

#Latex is needed to create plot titles
rcParams['text.usetex'] = True #set this to False if Latex distribution is not installed
rcParams["text.latex.preamble"] = r"\usepackage{amsmath}\usepackage{amsfonts}\usepackage{systeme}"
# %config InlineBackend.figure_format = 'retina'

# %%
def create_colormap(hex_color1, hex_color2, reverse=False):
    """
    Create a linearly interpolated colormap from two hex colors.

    -hex_color1: String, the first hex color (e.g., "#FF0000" for red)
    -hex_color2: String, the second hex color (e.g., "#0000FF" for blue)
    -reverse: Boolean, invert colors.
    
    Return: LinearSegmentedColormap
    """
    color1 = to_rgb(hex_color1)
    color2 = to_rgb(hex_color2)
    if reverse:
        colors = [color2, color1]
    else:
        colors = [color1, color2]
    cmap = LinearSegmentedColormap.from_list("custom_colormap", colors)

    return cmap

# %%
# a custom colormap
c_labels = "#000000"
yellow_map = create_colormap("#000000", "#FFFFFF", True)

# %%
@njit
def meshgrid(x, y):
    """
    This function replace np.meshgrid that is not supported by numba
    """
    xx = np.empty(shape=(x.size, y.size), dtype=x.dtype)
    yy = np.empty(shape=(x.size, y.size), dtype=y.dtype)
    for j in range(y.size):
        for k in range(x.size):
            xx[j,k] = k  # change to x[k] if indexing xy
            yy[j,k] = j  # change to y[j] if indexing xy
    return xx, yy
@njit
def calc_orbit(n_points, a, b, n_iter):
    """
    This function calculate orbits in a vectorized fashion.

    -n_points: lattice of initial conditions, n_points x n_points in [-1,1]x[-1,1]
    -a: first parameter of the dynamical system
    -b: second parameter of the dynamical system
    -n_iter: number of iterations

    Return: two ndarrays: x and y coordinates of every point of every orbit.
    """
    area = [[-1,1],[-1,1]]
    x = np.linspace(area[0][0],area[0][1],n_points)
    y = np.linspace(area[1][0],area[1][1],n_points)
    xx,yy = meshgrid(x,y)
    l_cx,l_cy=np.zeros(n_iter*n_points**2),np.zeros(n_iter*n_points**2)
    for i in range(n_iter):
        xx_new = np.sin(xx**2-yy**2 + a)
        yy_new = np.cos(2*xx*yy + b)
        xx = xx_new
        yy = yy_new
        l_cx[i*n_points**2:(i+1)*n_points**2] = xx.flatten()
        l_cy[i*n_points**2:(i+1)*n_points**2] = yy.flatten()
    return l_cx, l_cy

        # xx_new = np.sin(xx**1-yy**1 + a)
        # yy_new = np.cos(15*xx*yy + b)
        # xx = xx_new
        # yy = yy_new

# %%
import random

n_points = 1000
n_iter = 100
a, b = random.uniform(0, 5), random.uniform(0, 5)
l_cx, l_cy = calc_orbit(n_points, a, b, n_iter)

# %%
print(a, b)
# Out:
# 4.004236965815507 4.320648123734217

# %%
area = [[-1,1],[-1,1]]
h,_,_ = np.histogram2d(l_cx,l_cy,bins=3000,range=area)

# %%
fig, ax = plt.subplots(figsize=(10,6))

fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=None, hspace=None)
ax.imshow(np.log(h+1),vmin=0,vmax=5,cmap='Greys')
plt.xticks([]), plt.yticks([])
ax.set_title(r'$\begin{array}{lr} x_{t+1} = \sin(x_t^2-y_t^2 + %s) \\ y_{t+1} = \cos(2x_t y_t + %s) \end{array}$'%(a,b), 
             y=0.9, fontsize=15, color=c_labels )

# include my own legend with my own text  at the bottom
plt.text(0.83, -0.03, 'By:P_AstudilloE. Inspired by: @S_Conradi', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=7, color=c_labels)



plt.show()
